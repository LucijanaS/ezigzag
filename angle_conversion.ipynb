# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from scipy import special
# %matplotlib inline

# %%
dRa = np.asarray([-1.358, 0.054, -1.227, 1.915, -0.747, 1.35, 0.494])
dDec = np.asarray([0.966, 2.293, -1.387, -0.340, -2.644, 1.1, 0.12])

dy = dDec
dx = dRa
#dRa*np.sin(2*np.pi*((87 + dDec)/360))

plt.plot(dx, dy, '.')

#plt.gca().set_aspect('equal')
